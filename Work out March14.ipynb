# %% [markdown]
# ## Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# ## reading a csv file

# %%
df=pd.read_csv('./titanic.csv')

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ## Getting Sample

# %%
df.sample()
# Out:
#     PassengerId  Survived  Pclass  \
# 18           19       0.0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
#
#     Parch  Ticket  Fare  ... Embarked  WikiId  \
# 18      0  345763  18.0  ...        S  1280.0
#
#                                             Name_wiki Age_wiki  \
# 18  Vanderplancke, Mrs. Emelie Maria (née Vandemoo...     31.0
#
#            Hometown      Boarded        Destination Lifeboat Body Class
# 18  Pittem, Belgium  Southampton  Fremont, Ohio, US      NaN  NaN   3.0
#
# [1 rows x 21 columns]

# %%
df.sample(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 284           285       0.0       1
# 1141         1142       NaN       2
# 1163         1164       NaN       1
# 617           618       0.0       3
# 1012         1013       NaN       3
# 236           237       0.0       2
# 1229         1230       NaN       2
# 492           493       0.0       1
# 459           460       0.0       3
# 934           935       NaN       2
#
#                                                  Name     Sex    Age  SibSp  \
# 284                        Smith, Mr. Richard William    male    NaN      0
# 1141                            West, Miss. Barbara J  female   0.92      1
# 1163    Clark, Mrs. Walter Miller (Virginia McDowell)  female  26.00      1
# 617   Lobb, Mrs. William Arthur (Cordelia K Stanlick)  female  26.00      1
# 1012                                Kiernan, Mr. John    male    NaN      1
# 236                                 Hold, Mr. Stephen    male  44.00      1
# ...

# %% [markdown]
# ## Head

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.head(60)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1       0.0       3
# 1             2       1.0       1
# 2             3       1.0       3
# 3             4       1.0       1
# 4             5       0.0       3
# 5             6       0.0       3
# 6             7       0.0       1
# 7             8       0.0       3
# 8             9       1.0       3
# 9            10       1.0       2
# 10           11       1.0       3
# 11           12       1.0       1
# 12           13       0.0       3
# 13           14       0.0       3
# 14           15       0.0       3
# 15           16       1.0       2
# 16           17       0.0       3
# 17           18       1.0       2
# 18           19       0.0       3
# 19           20       1.0       3
# 20           21       0.0       2
# 21           22       1.0       2
# 22           23       1.0       3
# 23           24       1.0       1
# 24           25       0.0       3
# 25           26       1.0       3
# ...

# %% [markdown]
# ## Tail

# %%
df.tail()
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare  ... Embarked  WikiId  \
# 1304   NaN      0      0           A.5. 3236    8.0500  ...        S  1227.0
# 1305  39.0      0      0            PC 17758  108.9000  ...        C   229.0
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500  ...        S  1169.0
# 1307   NaN      0      0              359309    8.0500  ...        S  1289.0
# 1308   NaN      1      1                2668   22.3583  ...        C   702.0
#
#                                  Name_wiki Age_wiki  \
# ...

# %%
df.tail(50)
# Out:
#       PassengerId  Survived  Pclass  \
# 1259         1260       NaN       1
# 1260         1261       NaN       2
# 1261         1262       NaN       2
# 1262         1263       NaN       1
# 1263         1264       NaN       1
# 1264         1265       NaN       2
# 1265         1266       NaN       1
# 1266         1267       NaN       1
# 1267         1268       NaN       3
# 1268         1269       NaN       2
# 1269         1270       NaN       1
# 1270         1271       NaN       3
# 1271         1272       NaN       3
# 1272         1273       NaN       3
# 1273         1274       NaN       3
# 1274         1275       NaN       3
# 1275         1276       NaN       2
# 1276         1277       NaN       2
# 1277         1278       NaN       3
# 1278         1279       NaN       2
# 1279         1280       NaN       3
# 1280         1281       NaN       3
# 1281         1282       NaN       1
# 1282         1283       NaN       1
# 1283         1284       NaN       3
# ...

# %% [markdown]
# ## To find no of null values

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %% [markdown]
# ## To drop coloumns

# %%
df.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin          77.463713
# Embarked        0.152788
# WikiId          0.381971
# Name_wiki       0.381971
# Age_wiki        0.534759
# Hometown        0.381971
# Boarded         0.381971
# Destination     0.381971
# Lifeboat       61.650115
# Body           90.068755
# Class           0.381971
# dtype: float64

# %%
df.drop(columns=['Body','Lifeboat','Cabin'],inplace=True)

# %%
df.drop(columns='PassengerId',inplace=True)

# %%
df
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
df.isna().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         2
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %% [markdown]
# ### To Fill null values

# %%
Age_Mode=df.Age.mode()

# %%
df.Age.value_counts()
# Out:
# 24.0    47
# 22.0    43
# 21.0    41
# 30.0    40
# 18.0    39
#         ..
# 23.5     1
# 70.5     1
# 55.5     1
# 20.5     1
# 38.5     1
# Name: Age, Length: 98, dtype: int64

# %%
Age_Mode
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df.Age.fillna('Age_Mode',inplace=True)

# %%
df.isna().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         2
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
Fare_Mean=df.Fare.mean()

# %%
df.shape
# Out:
# (1309, 17)

# %%
df.Fare.fillna('Fare_Mean',inplace=True)

# %%
df
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex       Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %% [markdown]
# ## Group by

# %%
df.groupby(["Sex"])['Survived'].sum()
# Out:
# Sex
# female    233.0
# male      109.0
# Name: Survived, dtype: float64

# %%
df.groupby(["Boarded"])['Survived'].sum()
# Out:
# Boarded
# Belfast          0.0
# Cherbourg       93.0
# Queenstown      29.0
# Southampton    219.0
# Name: Survived, dtype: float64

# %% [markdown]
# ## Query

# %%
df.query("Boarded=='Southampton' & Age==24 & Survived==1.0")
# Out:
#      Survived  Pclass                                               Name  \
# 127       1.0       3                          Madsen, Mr. Fridtjof Arne
# 142       1.0       3  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 247       1.0       2                    Hamalainen, Mrs. William (Anna)
# 316       1.0       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 341       1.0       1                     Fortune, Miss. Alice Elizabeth
# 345       1.0       2                      Brown, Miss. Amelia "Mildred"
# 394       1.0       3  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...
# 437       1.0       2              Richards, Mrs. Sidney (Emily Hocking)
# 600       1.0       2  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...
# 615       1.0       2                                Herman, Miss. Alice
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Embarked  WikiId  \
# 127    male  24.0      0      0           C 17369  7.1417        S   993.0
# ...

# %% [markdown]
# ## Value counts

# %%
df.value_counts('Age')
# Out:
# Age
# Age_Mode    263
# 24.0         47
# 22.0         43
# 21.0         41
# 30.0         40
#            ...
# 11.5          1
# 26.5          1
# 24.5          1
# 20.5          1
# 0.17          1
# Length: 99, dtype: int64

# %%
df
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex       Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %% [markdown]
# ## Group by .....

# %%
Pclass_Survived=df.groupby(["Pclass"])['Survived'].sum()
Pclass_Survived
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %%
Embarked_Survived=df.groupby(["Embarked"])['Survived'].sum()

# %%
Embarked_Survived
# Out:
# Embarked
# C     93.0
# Q     30.0
# S    217.0
# Name: Survived, dtype: float64

# %%
Boarded_Survived=df.groupby(["Boarded"])['Survived'].sum()

# %%
Boarded_Survived
# Out:
# Boarded
# Belfast          0.0
# Cherbourg       93.0
# Queenstown      29.0
# Southampton    219.0
# Name: Survived, dtype: float64

# %%
df.isna().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %% [markdown]
# ## Q

# %%
ht_dts=df.query("Hometown=='London, England' & Boarded=='Southampton' & Destination=='New York City' &  Class==3.0 & Survived==0.0")

# %%
ht_dts
# Out:
#      Survived  Pclass                           Name   Sex       Age  SibSp  \
# 77        0.0       3       Moutal, Mr. Rahamin Haim  male  Age_Mode      0
# 87        0.0       3  Slocovski, Mr. Selman Francis  male  Age_Mode      0
# 90        0.0       3           Christmann, Mr. Emil  male      29.0      0
# 157       0.0       3                Corn, Mr. Harry  male      30.0      0
# 454       0.0       3            Peduzzi, Mr. Joseph  male  Age_Mode      0
# 464       0.0       3             Maisner, Mr. Simon  male  Age_Mode      0
# 589       0.0       3            Murdlin, Mr. Joseph  male  Age_Mode      0
# 837       0.0       3            Sirota, Mr. Maurice  male  Age_Mode      0
#
#      Parch           Ticket  Fare Embarked  WikiId  \
# 77       0           374746  8.05        S  1043.0
# 87       0  SOTON/OQ 392086  8.05        S  1221.0
# 90       0           343276  8.05        S   723.0
# 157      0  SOTON/OQ 392090  8.05        S   740.0
# ...
